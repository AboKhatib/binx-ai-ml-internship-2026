# %% [markdown]
# # Day 1 – Environment Setup
#
# ## BinX Tech AI & ML Internship
#
# This notebook verifies that my Python environment is working correctly.

# %%
print ("hello world")
print ("python is working")
# Out:
# hello world
# python is working

# %%
import numpy as np
import pandas as pd

print("NumPy version", np.__version__)
print ("Pandas version", pd.__version__)
# Out:
# NumPy version 2.3.5
# Pandas version 2.3.3

# %%
data = {
    "name": ["Ahmad" , "Sara" , "Omar"],
    "score": [85 , 92, 77]

}
df = pd.DataFrame(data)
df
# Out:
#     name  score
# 0  Ahmad     85
# 1   Sara     92
# 2   Omar     77

# %%
import matplotlib.pyplot as plt

x= [1, 2, 3, 4, 5]
y= [2, 4, 6, 8, 10]

plt.plot (x,y)
plt.xlabel ("X")
plt.ylabel ("Y")
plt.title ("Matplotlib Test")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
